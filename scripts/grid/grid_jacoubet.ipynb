# %%
import pandas as pd

# %%
# Number of sheets in row / columns
ATLAS_DIMS = (6, 9)

# Approximate sheets margins, in % of the image width/height
#          LEFT   RIGHT  TOP    BOTTOM
#MARGINS = [0.064, 0.07, 0.055, 0.06]

MARGINS = [0.044, 0.044, 0.07, 0.07]

def _jacoubet_sheet_dims(band: int, axis) -> int:
    """Return the number of grid lines (vertical or horizontal) in a sheet of the Jacoubet's Atlas."""
    match axis:
        case 0:  # Rows
            return 6 - (1 if band == 0 else 0)
        case 1:  # Columns
            return 5
        case _:
            raise ValueError(f"Invalid axis {axis}")

# %%
import pandas as pd


def grid_offset_for_band(band: int, axis: int, sheet_dims) -> int:
    """Get the offset to apply for a given band to get the starting position of a sheet in that band."""
    match axis:
        case 0:  # Rows
            offset = band * sheet_dims(band, 0) - band - 1
        case 1:  # Columns
            offset = band * sheet_dims(band, 1) - band
        case _:
            raise ValueError("Invalid axis %", axis)
    return max(0, offset)


def get_sheet_mask(
    grid: pd.DataFrame, atlas_x: int, atlas_y: int, sheet_dims
) -> pd.Series:
    """Calculate the grid-level boolean mask for the sheet at (atlas_x, atlas_y)."""
    row_offset = grid_offset_for_band(atlas_y, 0, sheet_dims)
    column_offset = grid_offset_for_band(atlas_x, 1, sheet_dims)

    return (
        (grid.column >= column_offset)
        & (grid.row >= row_offset)
        & (grid.column < column_offset + sheet_dims(atlas_x, 1))
        & (grid.row < row_offset + sheet_dims(atlas_y, 0))
    )


def compute_sheets_masks(grid: pd.DataFrame, sheet_dims_f):
    # Retrieve the coordinates of the grid axes to construct
    # the indices for the rows and columns of the grid.
    grid_row_steps = grid.Y.unique().tolist()
    grid_col_steps = grid.X.unique().tolist()

    # Assign the appropriate row and column to each point on the grid
    grid["row"] = grid.Y.apply(lambda y: grid_row_steps.index(y))
    grid["column"] = grid.X.apply(lambda x: grid_col_steps.index(x))

    sheet_counter = 0

    # Generate and apply the masks for the sheets.
    # ATLAS_DIMS defines an "atlas-level" grid whose 2D points are map sheets.
    for y_atlas in range(ATLAS_DIMS[0]):
        for x_atlas in range(ATLAS_DIMS[1]):
            sheet_counter += 1
            mask = get_sheet_mask(grid, x_atlas, y_atlas, sheet_dims_f)
            grid[sheet_counter] = mask

# %%
def make_gcps(
    grid: pd.DataFrame,
    sheet_ix: int,
    sheet: pd.Series,
    margins: list[int],
    sheet_dims_func,
):
    # mapX,mapY,sourceX,sourceY,enable,dX,dY,residual
    mask = grid[sheet_ix + 1]
    gcps = (
        grid[mask][["X", "Y"]]
        .rename(columns={"X": "mapX", "Y": "mapY"})
        .reset_index(drop=True)
    )

    sourceX = []
    sourceY = []

    atlas_y = sheet_ix // ATLAS_DIMS[1]  # row
    atlas_x = sheet_ix % ATLAS_DIMS[1]  # col

    cells_per_row = sheet_dims_func(atlas_y, 0)
    cells_per_column = sheet_dims_func(atlas_y, 1)

    delta = (
        (sheet.width - margins[0] - margins[1]) / (cells_per_column - 1),
        (sheet.height - margins[2] - margins[3]) / (cells_per_row - 1),
    )
    for pix in gcps.index:
        col = pix // sheet_dims_func(atlas_y, 0)
        row = pix % sheet_dims_func(atlas_y, 0)
        sourceX.append(col * delta[0])
        sourceY.append(row * delta[1])
    print(sheet)
    print(margins)
    print(delta)
    print(sheet_dims_func(atlas_x, 0))
    print(sheet_dims_func(atlas_y, 1))
    gcps["sourceX"] = sourceX
    gcps["sourceY"] = sourceY
    gcps["sourceX"] = gcps.sourceX + margins[0]
    gcps["sourceY"] = gcps.sourceY * -1.0 - margins[2]
    gcps["enabled"] = 1
    return gcps

# %%
def main():
    # Load data
    grid = pd.read_csv("grid_jacoubet.csv")
    # Add sheet masks
    compute_sheets_masks(grid, sheet_dims_f=_jacoubet_sheet_dims)
    # Save results
    grid.to_csv("output/grid.csv", index=False)

    sheet_dims_f = _jacoubet_sheet_dims
    sheets = pd.read_csv("dimensions.csv", sep=";")
    for ix, sheet in sheets.iterrows():
        margins = [
            MARGINS[0] * sheet.width,
            MARGINS[1] * sheet.width,
            MARGINS[2] * sheet.height,
            MARGINS[3] * sheet.height,
        ]
        print(margins)
        gcps = make_gcps(grid, ix, sheet, margins, sheet_dims_f)
        gcps.to_csv(f"output/{sheet.sheet}.points", index=False)

# %%
main()
# Out:
# [532.312, 532.312, 550.62, 550.62]
# sheet     Atlas_de_Jacoubet_-_01_et_02._Feuille_de_titre...
# width                                                 12098
# height                                                 7866
# Name: 0, dtype: object
# [532.312, 532.312, 550.62, 550.62]
# (2758.344, 1691.19)
# 5
# 5
# [282.304, 282.304, 477.47, 477.47]
# sheet     Atlas_de_Jacoubet_-_03._Partie_de_la_commune_d...
# width                                                  6416
# height                                                 6821
# Name: 1, dtype: object
# [282.304, 282.304, 477.47, 477.47]
# (1462.848, 1466.5149999999999)
# 6
# 5
# [281.424, 281.424, 475.72, 475.72]
# sheet     Atlas_de_Jacoubet_-_04._Partie_de_la_commune_d...
# width                                                  6396
# height                                                 6796
# Name: 2, dtype: object
# [281.424, 281.424, 475.72, 475.72]
# (1458.288, 1461.1399999999999)
# 6
# 5
# [281.424, 281.424, 468.02000000000004, 468.02000000000004]
# sheet     Atlas_de_Jacoubet_-_05._Partie_de_la_commune_d...
# width                                                  6396
# height                                                 6686
# Name: 3, dtype: object
# [281.424, 281.424, 468.02000000000004, 468.02000000000004]
# (1458.288, 1437.4899999999998)
# 6
# 5
# [279.88399999999996, 279.88399999999996, 467.32000000000005, 467.32000000000005]
# sheet     Atlas_de_Jacoubet_-_06._Partie_de_la_commune_d...
# width                                                  6361
# height                                                 6676
# Name: 4, dtype: object
# [279.88399999999996, 279.88399999999996, 467.32000000000005, 467.32000000000005]
# (1450.308, 1435.3400000000001)
# 6
# 5
# [277.68399999999997, 277.68399999999997, 470.12000000000006, 470.12000000000006]
# sheet     Atlas_de_Jacoubet_-_07._Barrière_de_la_Villett...
# width                                                  6311
# height                                                 6716
# Name: 5, dtype: object
# [277.68399999999997, 277.68399999999997, 470.12000000000006, 470.12000000000006]
# (1438.908, 1443.94)
# 6
# 5
# [544.764, 544.764, 560.7700000000001, 560.7700000000001]
# sheet     Atlas_de_Jacoubet_-_08_et_09._Plan_d'assemblag...
# width                                                 12381
# height                                                 8011
# Name: 6, dtype: object
# [544.764, 544.764, 560.7700000000001, 560.7700000000001]
# (2822.8680000000004, 1722.3649999999998)
# 6
# 5
# [286.264, 286.264, 563.57, 563.57]
# sheet     Atlas_de_Jacoubet_-_10._Route_de_Neuilly_à_Par...
# width                                                  6506
# height                                                 8051
# Name: 7, dtype: object
# [286.264, 286.264, 563.57, 563.57]
# (1483.368, 1730.9650000000001)
# 6
# 5
# [279.224, 279.224, 561.47, 561.47]
# sheet     Atlas_de_Jacoubet_-_11._Hospice_Beaujon_et_ses...
# width                                                  6346
# height                                                 8021
# Name: 8, dtype: object
# [279.224, 279.224, 561.47, 561.47]
# (1446.888, 1724.5149999999999)
# 6
# 5
# [277.024, 277.024, 559.72, 559.72]
# sheet     Atlas_de_Jacoubet_-_12._Abattoir_du_Roule_et_s...
# width                                                  6296
# height                                                 7996
# Name: 9, dtype: object
# [277.024, 277.024, 559.72, 559.72]
# (1435.4879999999998, 1375.312)
# 5
# 5
# [280.32399999999996, 280.32399999999996, 574.07, 574.07]
# sheet     Atlas_de_Jacoubet_-_13._Collège_Bourbon_et_ses...
# width                                                  6371
# height                                                 8201
# Name: 10, dtype: object
# [280.32399999999996, 280.32399999999996, 574.07, 574.07]
# (1452.5880000000002, 1410.5720000000001)
# 6
# 5
# [276.364, 276.364, 557.2700000000001, 557.2700000000001]
# sheet     Atlas_de_Jacoubet_-_14._Académie_Royale_de_Mus...
# width                                                  6281
# height                                                 7961
# Name: 11, dtype: object
# [276.364, 276.364, 557.2700000000001, 557.2700000000001]
# (1432.0680000000002, 1369.292)
# 6
# 5
# [276.804, 276.804, 559.0200000000001, 559.0200000000001]
# sheet     Atlas_de_Jacoubet_-_15._Eglise_St_Laurent_et_s...
# width                                                  6291
# height                                                 7986
# Name: 12, dtype: object
# [276.804, 276.804, 559.0200000000001, 559.0200000000001]
# (1434.348, 1373.5919999999999)
# 6
# 5
# [274.38399999999996, 274.38399999999996, 561.47, 561.47]
# sheet     Atlas_de_Jacoubet_-_16._Hospice_St_Louis_et_se...
# width                                                  6236
# height                                                 8021
# Name: 13, dtype: object
# [274.38399999999996, 274.38399999999996, 561.47, 561.47]
# (1421.808, 1379.6119999999999)
# 6
# 5
# [273.724, 273.724, 559.37, 559.37]
# sheet     Atlas_de_Jacoubet_-_17._Commune_de_Belleville_...
# width                                                  6221
# height                                                 7991
# Name: 14, dtype: object
# [273.724, 273.724, 559.37, 559.37]
# (1418.388, 1374.452)
# 6
# 5
# [278.344, 278.344, 566.0200000000001, 566.0200000000001]
# sheet     Atlas_de_Jacoubet_-_18._Commune_de_Belleville_...
# width                                                  6326
# height                                                 8086
# Name: 15, dtype: object
# [278.344, 278.344, 566.0200000000001, 566.0200000000001]
# (1442.328, 1390.792)
# 6
# 5
# [298.716, 298.716, 572.5300000000001, 572.5300000000001]
# sheet     Atlas_de_Jacoubet_-_19._Partie_de_la_commune_d...
# width                                                  6789
# height                                                 8179
# Name: 16, dtype: object
# [298.716, 298.716, 572.5300000000001, 572.5300000000001]
# (1547.8919999999998, 1406.788)
# 6
# 5
# [299.24399999999997, 299.24399999999997, 578.2700000000001, 578.2700000000001]
# sheet     Atlas_de_Jacoubet_-_20._Eglise_St_Pierre,_Gros...
# width                                                  6801
# height                                                 8261
# Name: 17, dtype: object
# [299.24399999999997, 299.24399999999997, 578.2700000000001, 578.2700000000001]
# (1550.6280000000002, 1420.8919999999998)
# 6
# 5
# [300.608, 300.608, 580.44, 580.44]
# sheet     Atlas_de_Jacoubet_-_21._Champs-Elysées_et_leur...
# width                                                  6832
# height                                                 8292
# Name: 18, dtype: object
# [300.608, 300.608, 580.44, 580.44]
# (1557.696, 1426.2239999999997)
# 5
# 5
# [302.764, 302.764, 582.12, 582.12]
# sheet     Atlas_de_Jacoubet_-_22._Tuileries_et_leurs_env...
# width                                                  6881
# height                                                 8316
# Name: 19, dtype: object
# [302.764, 302.764, 582.12, 582.12]
# (1568.868, 1430.352)
# 6
# 5
# [298.144, 298.144, 570.57, 570.57]
# sheet     Atlas_de_Jacoubet_-_23._Eglise_St_Eustache_et_...
# width                                                  6776
# height                                                 8151
# Name: 20, dtype: object
# [298.144, 298.144, 570.57, 570.57]
# (1544.9279999999999, 1401.9720000000002)
# 6
# 5
# [296.82399999999996, 296.82399999999996, 570.22, 570.22]
# sheet     Atlas_de_Jacoubet_-_24._Eglise_St_Nicolas_des_...
# width                                                  6746
# height                                                 8146
# Name: 21, dtype: object
# [296.82399999999996, 296.82399999999996, 570.22, 570.22]
# (1538.0880000000002, 1401.1119999999999)
# 6
# 5
# [296.296, 296.296, 572.32, 572.32]
# sheet     Atlas_de_Jacoubet_-_25._Théâtres_de_la_Gaîté_e...
# width                                                  6734
# height                                                 8176
# Name: 22, dtype: object
# [296.296, 296.296, 572.32, 572.32]
# (1535.3519999999999, 1406.2720000000002)
# 6
# 5
# [294.404, 294.404, 567.07, 567.07]
# sheet     Atlas_de_Jacoubet_-_26._Abattoir_Ménilmontant_...
# width                                                  6691
# height                                                 8101
# Name: 23, dtype: object
# [294.404, 294.404, 567.07, 567.07]
# (1525.5479999999998, 1393.372)
# 6
# 5
# [295.724, 295.724, 571.2700000000001, 571.2700000000001]
# sheet     Atlas_de_Jacoubet_-_27._Cimetière_du_Père-Lach...
# width                                                  6721
# height                                                 8161
# Name: 24, dtype: object
# [295.724, 295.724, 571.2700000000001, 571.2700000000001]
# (1532.388, 1403.6919999999998)
# 6
# 5
# [293.304, 293.304, 566.37, 566.37]
# sheet     Atlas_de_Jacoubet_-_28._Barrière_de_la_Cunette...
# width                                                  6666
# height                                                 8091
# Name: 25, dtype: object
# [293.304, 293.304, 566.37, 566.37]
# (1519.848, 1391.652)
# 6
# 5
# [292.33599999999996, 292.33599999999996, 564.83, 564.83]
# sheet     Atlas_de_Jacoubet_-_29._Champ_de_Mars_et_ses_e...
# width                                                  6644
# height                                                 8069
# Name: 26, dtype: object
# [292.33599999999996, 292.33599999999996, 564.83, 564.83]
# (1514.8319999999999, 1387.868)
# 6
# 5
# [292.864, 292.864, 566.0200000000001, 566.0200000000001]
# sheet     Atlas_de_Jacoubet_-_30._Hôtel_Royal_des_Invali...
# width                                                  6656
# height                                                 8086
# Name: 27, dtype: object
# [292.864, 292.864, 566.0200000000001, 566.0200000000001]
# (1517.5680000000002, 1390.792)
# 5
# 5
# [295.50399999999996, 295.50399999999996, 569.73, 569.73]
# sheet     Atlas_de_Jacoubet_-_31._Eglise_St_Sulpice_et_s...
# width                                                  6716
# height                                                 8139
# Name: 28, dtype: object
# [295.50399999999996, 295.50399999999996, 569.73, 569.73]
# (1531.248, 1399.9080000000001)
# 6
# 5
# [295.724, 295.724, 568.47, 568.47]
# sheet     Atlas_de_Jacoubet_-_32._Palais_de_Justice_et_s...
# width                                                  6721
# height                                                 8121
# Name: 29, dtype: object
# [295.724, 295.724, 568.47, 568.47]
# (1532.388, 1396.812)
# 6
# 5
# [294.18399999999997, 294.18399999999997, 569.1700000000001, 569.1700000000001]
# sheet     Atlas_de_Jacoubet_-_33._Ile_Saint-Louis_et_ses...
# width                                                  6686
# height                                                 8131
# Name: 30, dtype: object
# [294.18399999999997, 294.18399999999997, 569.1700000000001, 569.1700000000001]
# (1524.408, 1398.532)
# 6
# 5
# [293.74399999999997, 293.74399999999997, 567.7700000000001, 567.7700000000001]
# sheet     Atlas_de_Jacoubet_-_34.Place_de_la_Bastille_et...
# width                                                  6676
# height                                                 8111
# Name: 31, dtype: object
# [293.74399999999997, 293.74399999999997, 567.7700000000001, 567.7700000000001]
# (1522.1280000000002, 1395.0919999999999)
# 6
# 5
# [293.74399999999997, 293.74399999999997, 570.22, 570.22]
# sheet     Atlas_de_Jacoubet_-_35._Manufacture_des_Glaces...
# width                                                  6676
# height                                                 8146
# Name: 32, dtype: object
# [293.74399999999997, 293.74399999999997, 570.22, 570.22]
# (1522.1280000000002, 1401.1119999999999)
# 6
# 5
# [299.24399999999997, 299.24399999999997, 570.2900000000001, 570.2900000000001]
# sheet     Atlas_de_Jacoubet_-_36._Barrière_du_Trône_et_s...
# width                                                  6801
# height                                                 8147
# Name: 33, dtype: object
# [299.24399999999997, 299.24399999999997, 570.2900000000001, 570.2900000000001]
# (1550.6280000000002, 1401.284)
# 6
# 5
# [295.724, 295.724, 571.97, 571.97]
# sheet     Atlas_de_Jacoubet_-_37._Plaine_de_Grenelle_(ou...
# width                                                  6721
# height                                                 8171
# Name: 34, dtype: object
# [295.724, 295.724, 571.97, 571.97]
# (1532.388, 1405.4119999999998)
# 6
# 5
# [296.868, 296.868, 570.6400000000001, 570.6400000000001]
# sheet     Atlas_de_Jacoubet_-_38._Plaine_de_Grenelle_(es...
# width                                                  6747
# height                                                 8152
# Name: 35, dtype: object
# [296.868, 296.868, 570.6400000000001, 570.6400000000001]
# (1538.3159999999998, 1402.1439999999998)
# 6
# 5
# [298.716, 298.716, 570.6400000000001, 570.6400000000001]
# sheet     Atlas_de_Jacoubet_-_39._Barrière_du_Maine_et_s...
# width                                                  6789
# height                                                 8152
# Name: 36, dtype: object
# [298.716, 298.716, 570.6400000000001, 570.6400000000001]
# (1547.8919999999998, 1402.1439999999998)
# 5
# 5
# [294.18399999999997, 294.18399999999997, 566.0200000000001, 566.0200000000001]
# sheet     Atlas_de_Jacoubet_-_40._Barrière_du_Mont-Parna...
# width                                                  6686
# height                                                 8086
# Name: 37, dtype: object
# [294.18399999999997, 294.18399999999997, 566.0200000000001, 566.0200000000001]
# (1524.408, 1390.792)
# 6
# 5
# [297.39599999999996, 297.39599999999996, 569.1700000000001, 569.1700000000001]
# sheet     Atlas_de_Jacoubet_-_41._Hôpital_Militaire_du_V...
# width                                                  6759
# height                                                 8131
# Name: 38, dtype: object
# [297.39599999999996, 297.39599999999996, 569.1700000000001, 569.1700000000001]
# (1541.0520000000001, 1398.532)
# 6
# 5
# [294.93199999999996, 294.93199999999996, 565.74, 565.74]
# sheet     Atlas_de_Jacoubet_-_42._Jardin_du_Roi_et_ses_e...
# width                                                  6703
# height                                                 8082
# Name: 39, dtype: object
# [294.93199999999996, 294.93199999999996, 565.74, 565.74]
# (1528.284, 1390.104)
# 6
# 5
# [300.43199999999996, 300.43199999999996, 568.5400000000001, 568.5400000000001]
# sheet     Atlas_de_Jacoubet_-_43._Salpétrière,_Hospice_d...
# width                                                  6828
# height                                                 8122
# Name: 40, dtype: object
# [300.43199999999996, 300.43199999999996, 568.5400000000001, 568.5400000000001]
# (1556.784, 1396.984)
# 6
# 5
# [296.38399999999996, 296.38399999999996, 573.1600000000001, 573.1600000000001]
# sheet     Atlas_de_Jacoubet_-_44._Barrière_de_Charenton,...
# width                                                  6736
# height                                                 8188
# Name: 41, dtype: object
# [296.38399999999996, 296.38399999999996, 573.1600000000001, 573.1600000000001]
# (1535.808, 1408.336)
# 6
# 5
# [298.584, 298.584, 573.37, 573.37]
# sheet     Atlas_de_Jacoubet_-_45._Barrière_de_St_Mandé_e...
# width                                                  6786
# height                                                 8191
# Name: 42, dtype: object
# [298.584, 298.584, 573.37, 573.37]
# (1547.208, 1408.852)
# 6
# 5
# [275.83599999999996, 275.83599999999996, 560.35, 560.35]
# sheet     Atlas_de_Jacoubet_-_46._Nomenclature_-_BHVP.jpg
# width                                                6269
# height                                               8005
# Name: 43, dtype: object
# [275.83599999999996, 275.83599999999996, 560.35, 560.35]
# (1429.3319999999999, 1376.86)
# 6
# 5
# [278.388, 278.388, 564.69, 564.69]
# sheet     Atlas_de_Jacoubet_-_47._Nomenclature_-_BHVP.jpg
# width                                                6327
# height                                               8067
# Name: 44, dtype: object
# [278.388, 278.388, 564.69, 564.69]
# (1442.556, 1387.524)
# 6
# 5
# [300.256, 300.256, 572.0400000000001, 572.0400000000001]
# sheet     Atlas_de_Jacoubet_-_48._Nomenclature_et_partie...
# width                                                  6824
# height                                                 8172
# Name: 45, dtype: object
# [300.256, 300.256, 572.0400000000001, 572.0400000000001]
# (1555.8719999999998, 1405.584)
# 5
# 5
# [299.24399999999997, 299.24399999999997, 575.47, 575.47]
# sheet     Atlas_de_Jacoubet_-_49._Barrière_d'Enfer_et_se...
# width                                                  6801
# height                                                 8221
# Name: 46, dtype: object
# [299.24399999999997, 299.24399999999997, 575.47, 575.47]
# (1550.6280000000002, 1414.012)
# 6
# 5
# [299.24399999999997, 299.24399999999997, 575.47, 575.47]
# sheet     Atlas_de_Jacoubet_-_50._Barrière_Croulebarbe_e...
# width                                                  6801
# height                                                 8221
# Name: 47, dtype: object
# [299.24399999999997, 299.24399999999997, 575.47, 575.47]
# (1550.6280000000002, 1414.012)
# 6
# 5
# [294.976, 294.976, 571.1300000000001, 571.1300000000001]
# sheet     Atlas_de_Jacoubet_-_51._Barrière_d'Italie_et_s...
# width                                                  6704
# height                                                 8159
# Name: 48, dtype: object
# [294.976, 294.976, 571.1300000000001, 571.1300000000001]
# (1528.5120000000002, 1403.348)
# 6
# 5
# [296.38399999999996, 296.38399999999996, 569.5200000000001, 569.5200000000001]
# sheet     Atlas_de_Jacoubet_-_52._Nomenclature_des_monum...
# width                                                  6736
# height                                                 8136
# Name: 49, dtype: object
# [296.38399999999996, 296.38399999999996, 569.5200000000001, 569.5200000000001]
# (1535.808, 1399.3919999999998)
# 6
# 5
# [324.32399999999996, 324.32399999999996, 656.8800000000001, 656.8800000000001]
# sheet     Atlas_de_Jacoubet_-_Plan_réduit_du_Plan_généra...
# width                                                  7371
# height                                                 9384
# Name: 50, dtype: object
# [324.32399999999996, 324.32399999999996, 656.8800000000001, 656.8800000000001]
# (1680.5880000000002, 1614.0479999999998)
# 6
# 5
# [325.116, 325.116, 651.4200000000001, 651.4200000000001]
# sheet     Atlas_de_Jacoubet_-_Plan_réduit_du_Plan_généra...
# width                                                  7389
# height                                                 9306
# Name: 51, dtype: object
# [325.116, 325.116, 651.4200000000001, 651.4200000000001]
# (1684.692, 1600.632)
# 6
# 5
